# %% [markdown]
# # Planificación y Desarrollo de una Aplicación
#
# ## Desafío:
#
# El objetivo de este desafío es desarrollar una aplicación para resolver un problema determinado. Antes de comenzar con la programación, es necesario crear un plan en forma de pseudocódigo que sirva como guía. Esta planificación es esencial para estructurar correctamente la solución y facilitar su implementación en código.
#
# ### Etapas del Desafío:
#
# 1. **Generación del Pseudocódigo**:
#    - Describir, en pasos lógicos, cómo funcionará la aplicación.
#    - Incluir las operaciones principales que realizará la aplicación de acuerdo al problema que se debe resolver.
#    - Asegurarse de que cada funcionalidad esté clara y bien definida en el pseudocódigo para evitar confusión durante la fase de implementación.
#    - Anticipar posibles interacciones del usuario con el sistema y cómo se manejarán los datos.
#
# 2. **Desarrollo del Código**:
#    - Basarse en el pseudocódigo previamente generado para escribir el código que implemente la solución.
#    - Seguir el plan estructurado en el pseudocódigo y ajustarlo según sea necesario durante el desarrollo.
#    - Garantizar que todas las funcionalidades y casos previstos en el pseudocódigo estén reflejados en el código final.
#
# Este enfoque sistemático asegura que cualquier problema que se esté abordando tenga una solución bien planificada y organizada.

# %% [markdown]
# # Ejemplo 1: Seguidor de Gastos Mensuales
#
# ## Declaración del Problema:
#
# Imagina que formas parte de un pequeño equipo de negocio, y tu gerente se ha acercado a ti con una tarea. Quieren que crees un programa fácil de usar para ayudar a rastrear los gastos mensuales. Tu programa debe permitir a los usuarios ingresar gastos diarios y, al final del mes, calcular sin esfuerzo el gasto total.

# %%
# INICIO
# DECLARAR gastos COMO LISTA VACÍA
# DECLARAR totalGasto COMO NÚMERO
# totalGasto <- 0
# IMPRIMIR "Bienvenido al Seguidor de Gastos Mensuales"
# PARA cada día EN el mes HACER
# IMPRIMIR "Ingrese el gasto del día ", día, " (o escriba 'fin' para terminar):"
# LEER gasto
# SI gasto ES igual a 'fin' ENTONCES
# SALIR DEL BUCLE
# FIN SI
# AÑADIR gasto A la lista gastos
# totalGasto <- totalGasto + gasto
# FIN PARA
# IMPRIMIR "Gasto total del mes: ", totalGasto
# IMPRIMIR "Detalles de los gastos: ", gastos
# FIN

# %%
gastos = []
totalGasto = 0
print("Bienvenido al Seguidor de Gastos Mensuales")
dia_del_mes = 1
while dia_del_mes <= 30 :
    print("Ingrese el gasto del día ", dia_del_mes, " (o escriba 'fin' para terminar):")
    input_gasto= input()
    while input_gasto.lower() != "fin":
        
        totalGasto += float(input_gasto)
        gastos.append(input_gasto)
        input_gasto = input()
    dia_del_mes +=1
print("Gasto total del mes:  {}".format(totalGasto))
print("Detalles de los gastos:" , gastos)
# Out:
# Bienvenido al Seguidor de Gastos Mensuales
# Ingrese el gasto del día  1  (o escriba 'fin' para terminar):
#  50
#  40
#  fin
# Ingrese el gasto del día  2  (o escriba 'fin' para terminar):
#  60
#  90
#  fin
# Gasto total del mes:  240.0
# Detalles de los gastos: ['50', '40', '60', '90']

# %% [markdown]
# # Inventario de Tienda en Línea
#
# ## Declaración del Problema:
#
# Se te ha encargado crear un programa simple para una tienda en línea. El programa debería ayudar a gestionar el inventario de productos disponibles en la tienda. El inventario consta de varios productos con sus respectivos nombres, precios y cantidades en stock. Tu programa debe tener las siguientes características:
#
# - Inicializar un inventario vacío para empezar.
# - Permitir al usuario añadir nuevos productos al inventario. Cada producto debe tener un nombre, precio y cantidad inicial en stock.
# - Mostrar el inventario actual, mostrando el nombre, precio y cantidad de cada producto.
# - Permitir al usuario buscar un producto específico por nombre y ver sus detalles (precio y cantidad).
# - Habilitar al usuario para actualizar la cantidad de un producto específico en stock.
# - Implementar una función para calcular y mostrar el valor total de todo el inventario.

# %% [markdown]
# - Create an empty List for inventory
# - while the user didn't type fin they can select a function
# - Create a function named insert_item to insert to inventory named as add_to_inventory
# - this function take the name , price and the quantity of a product and append it to the inventory list as a dictionary if item exist print "This item already exists."
# - create a function named as find_item that receive a name of an item and print the details of a specific product
#   if item exists print "item: item name\n price: price and quantity: quantity"
#   if item  is not in the list print "There isn't such an item"
# - create a function to update the details of a specific product, This function recive the  product name, price and the quantity and update in in the list if item  is not in the list print " {name} doesn't exist in the inventory"
# - create a function that print the total value of the inventory as "The total value of the inventory is {totalvalue}", if the inventory is empty print "There is no item in the inventory".

# %%
# La tienda online
inventory = []


def insert_item(name, price, quantity):
    for i in inventory:
        if name == i["name"]:
            print("This item already exists.")
            return
    item = {
        "name": name,
        "price": price,
        "quantity": quantity,
    }
    inventory.append(item)
    return


def update_item(name, price, quantity):
    if find_item(name) == False:
        print("{} doesn't exist in the inventory".format(name))
        return 
    for item in inventory:
        if item["name"] == name:
            item["price"] = price
            item["quantity"] = quantity
            print("item: {0}   | price: {1}  | quantity: {2}".format(item["name"], item["price"], item["quantity"]))
            break
    return

def find_item(item_name):
    for item in inventory:
        if item["name"] == item_name:
            print("item: {0}   | price: {1}  | quantity: {2}".format(item["name"], item["price"], item["quantity"]))
            return True
            
    print("{0} doesn't exist in the inventory".format(item_name))
    return False


def total_value():
    if len(inventory) == 0:
        print("There is no item in the inventory")
        return
    total_value = 0
    for item in inventory:
        total_value += item["price"] * item["quantity"]
    print("The total value of the inventory is {0}".format(total_value))


print(
    "Please enter insert an to insert item | update to update an item | find to find an item | total to see the total value of the inventory | finish to exit")
input_command = input()
while input_command.strip().lower() != "finish":
    match input_command.lower().strip():
        case "insert":
            try:
                name = input("Please enter the product name: ")
                price = float(input("please enter the product price: "))
                quantity = float(input("please enter the quantity of the product: "))
            except Exception as e:
                print("The following error has ocurred\n{0}".format(e))
            else:
                insert_item(name, price, quantity)    
        case "update":
            name = input("Please enter the product name: ")
            price = float(input("please enter the product price: "))
            quantity = float(input("please enter the quantity of the product"))
            update_item(name, price, quantity)
        case "find":
            name = input("Please enter the product name: ")
            find_item(name)
        case "total":
            total_value()
        case _:
            print("Undefined Command")
    print(
        "Please enter insert an to insert item | update to update an item | find to find an item | total to see the total value of the inventory | finish to exit")
    input_command = input()
# Out:
# Please enter insert an to insert item | update to update an item | find to find an item | total to see the total value of the inventory | finish to exit
#  finish

# %% [markdown]
# # Gestor de Tareas
#
# ## Declaración del Problema:
#
# Se te ha encargado crear un programa que ayude a gestionar una lista de tareas. El programa debe permitir a los usuarios agregar, eliminar y visualizar tareas, así como marcar las tareas como completadas. a aplicación debe tener las siguientes características:
#
# - Inicializar una lista vacía para las tareas.
# - Permitir al usuario agregar una nueva tarea con una descripción.
# - Mostrar todas las tareas actuales, indicando cuáles están completadas y cuáles no.
# - Permitir al usuario marcar una tarea como completada.
# - Permitir al usuario eliminar una tarea de la lista.
# - Implementar una opción para salir del programa.
#
# El programa debe ser fácil de usar y manejar la entrada del usuario de manera adecuada.

# %%
tareas = []
def neuvo_tarea(discripcion):
    tareas.append({
        "discripcion" : discripcion,
        "completada" : False,
    })
    return
def cumplir_tarea(discripcion):
    for tarea in tareas:
        if tarea["discripcion"] == discripcion:
            tarea["completada"] = True
    return
def show_tareas():
    for index ,  tarea in enumerate(tareas):
        print(f' {index}. {tarea["discripcion"]} is {"Done" if tarea["completada"] else "Open"}')
def del_tarea(discripcion):
    for tarea in tareas:
        if tarea["discripcion"] == discripcion:
            print("Find ", discripcion)
            tareas.remove(tarea)
            break

print("Please enter add to add a task | remove to remove a task | complete to mark a task as completed | show to show all the tasks |finish to exit the program")
user_input=input()
while user_input.strip().lower() != "finish":
    match user_input.strip().lower():
        case "add":
            discripcion = input("please enter the task discription").strip()
            neuvo_tarea(discripcion)
        case "remove" :
            discripcion = input("please enter the task discription").strip()
            del_tarea(discripcion)
        case "complete":
            discripcion = input("please enter the task discription").strip()
            cumplir_tarea(discripcion)
        case "show":
            show_tareas()
        case _:
            print("undefined command")
    print("Please enter add to add a task | remove to remove a task | complete to mark a task as completed | finish to exit the program")
    user_input=input()
# Out:
# Please enter add to add a task | remove to remove a task | complete to mark a task as completed | show to show all the tasks |finish to exit the program
#  fgfhfg
# undefined command
# Please enter add to add a task | remove to remove a task | complete to mark a task as completed | finish to exit the program
#  vbcvb
# undefined command
# Please enter add to add a task | remove to remove a task | complete to mark a task as completed | finish to exit the program
#  finish
